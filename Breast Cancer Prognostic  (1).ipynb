# %%
# import libraries
import pandas as pd # for data manupulation or analysis
import numpy as np # for numeric calculation
import matplotlib.pyplot as plt # for data visualization
import seaborn as sns # for data visualization

# %%
df=pd.read_csv("wpbc.data")

# %%
names=[ 'status', 'time', 'mean_radius', 'mean_texture', 'mean_perimeter', 'mean_area', 'mean_smoothness','mean_compactness','mean_concavity',
'mean_concavepoints', 'mean_symmetry', 'mean_fractaldim', 'SE_radius','SE_texture','SE_perimeter','SE_area','SE_smoothness',
'SE_compactness','SE_concavity','SE_concavepoints', 'SE_symmetry', 'SE_fractaldim', 'worst_radius', 'worst_texture',       
'worst_perimeter', 'worst_area','worst_smoothness','worst_compactness', 'worst_concavity','worst_concavepoints', 'worst_symmetry',
'worst_fractaldim', 'tsize', 'pnodes']

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wpbc.data', names = names)

# %%
df.head()
# Out:
#        status  time  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 119513      N    31        18.02         27.60          117.50     1013.0
# 8423        N    61        17.99         10.38          122.80     1001.0
# 842517      N   116        21.37         17.44          137.50     1373.0
# 843483      N   123        11.42         20.38           77.58      386.1
# 843584      R    27        20.29         14.34          135.10     1297.0
#
#         mean_smoothness  mean_compactness  mean_concavity  mean_concavepoints  \
# 119513          0.09489            0.1036          0.1086             0.07055
# 8423            0.11840            0.2776          0.3001             0.14710
# 842517          0.08836            0.1189          0.1255             0.08180
# 843483          0.14250            0.2839          0.2414             0.10520
# 843584          0.10030            0.1328          0.1980             0.10430
#
# ...

# %%
df.tail(6)
# Out:
#         status  time  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 9411300      N     3        14.72         25.26           99.28      657.5
# 942640       N    10        22.52         21.92          146.90     1597.0
# 943471       N     8        15.44         31.18          101.00      740.4
# 94547        N    12        17.17         29.19          110.00      915.3
# 947204       R     3        21.42         22.84          145.00     1440.0
# 947489       N     6        16.70         28.13          110.30      885.4
#
#          mean_smoothness  mean_compactness  mean_concavity  \
# 9411300          0.11740           0.21120         0.17290
# 942640           0.07592           0.09162         0.06862
# 943471           0.09399           0.10620         0.13750
# 94547            0.08952           0.06655         0.06583
# 947204           0.10700           0.19390         0.23800
# 947489           0.08896           0.11310         0.10120
#
# ...

# %%
df.shape
# Out:
# (198, 34)

# %%
df.isnull().sum()
# Out:
# status                 0
# time                   0
# mean_radius            0
# mean_texture           0
# mean_perimeter         0
# mean_area              0
# mean_smoothness        0
# mean_compactness       0
# mean_concavity         0
# mean_concavepoints     0
# mean_symmetry          0
# mean_fractaldim        0
# SE_radius              0
# SE_texture             0
# SE_perimeter           0
# SE_area                0
# SE_smoothness          0
# SE_compactness         0
# SE_concavity           0
# SE_concavepoints       0
# SE_symmetry            0
# SE_fractaldim          0
# worst_radius           0
# worst_texture          0
# worst_perimeter        0
# worst_area             0
# worst_smoothness       0
# worst_compactness      0
# worst_concavity        0
# worst_concavepoints    0
# worst_symmetry         0
# worst_fractaldim       0
# tsize                  0
# pnodes                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[df['pnodes']=='?']
# Out:
#        status  time  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 844359      N    60        18.98         19.61          124.40     1112.0
# 854253      N    12        16.74         21.59          110.10      869.5
# 877500      N    72        14.45         20.22           94.49      642.7
# 947204      R     3        21.42         22.84          145.00     1440.0
#
#         mean_smoothness  mean_compactness  mean_concavity  mean_concavepoints  \
# 844359          0.09087            0.1237          0.1213             0.08910
# 854253          0.09610            0.1336          0.1348             0.06018
# 877500          0.09872            0.1206          0.1180             0.05980
# 947204          0.10700            0.1939          0.2380             0.13180
#
#         ...  worst_perimeter  worst_area  worst_smoothness  worst_compactness  \
# 844359  ...            152.6      1593.0            0.1144             0.3371
# ...

# %%
df['pnodes'].replace('?',np.nan,inplace=True )
df['pnodes'].fillna(value=0,inplace=True)

df['pnodes']=df['pnodes'].astype(int)
df['pnodes'].replace(0,df['pnodes'].mean(),inplace=True )

# %%
df.loc[df['pnodes']=='?']
# Out:
# Empty DataFrame
# Columns: [status, time, mean_radius, mean_texture, mean_perimeter, mean_area, mean_smoothness, mean_compactness, mean_concavity, mean_concavepoints, mean_symmetry, mean_fractaldim, SE_radius, SE_texture, SE_perimeter, SE_area, SE_smoothness, SE_compactness, SE_concavity, SE_concavepoints, SE_symmetry, SE_fractaldim, worst_radius, worst_texture, worst_perimeter, worst_area, worst_smoothness, worst_compactness, worst_concavity, worst_concavepoints, worst_symmetry, worst_fractaldim, tsize, pnodes]
# Index: []
#
# [0 rows x 34 columns]

# %%
df
# Out:
#        status  time  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 119513      N    31        18.02         27.60          117.50     1013.0
# 8423        N    61        17.99         10.38          122.80     1001.0
# 842517      N   116        21.37         17.44          137.50     1373.0
# 843483      N   123        11.42         20.38           77.58      386.1
# 843584      R    27        20.29         14.34          135.10     1297.0
# ...       ...   ...          ...           ...             ...        ...
# 942640      N    10        22.52         21.92          146.90     1597.0
# 943471      N     8        15.44         31.18          101.00      740.4
# 94547       N    12        17.17         29.19          110.00      915.3
# 947204      R     3        21.42         22.84          145.00     1440.0
# 947489      N     6        16.70         28.13          110.30      885.4
#
#         mean_smoothness  mean_compactness  mean_concavity  mean_concavepoints  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 119513 to 947489
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   status               198 non-null    object
#  1   time                 198 non-null    int64
#  2   mean_radius          198 non-null    float64
#  3   mean_texture         198 non-null    float64
#  4   mean_perimeter       198 non-null    float64
#  5   mean_area            198 non-null    float64
#  6   mean_smoothness      198 non-null    float64
#  7   mean_compactness     198 non-null    float64
#  8   mean_concavity       198 non-null    float64
#  9   mean_concavepoints   198 non-null    float64
#  10  mean_symmetry        198 non-null    float64
#  11  mean_fractaldim      198 non-null    float64
#  12  SE_radius            198 non-null    float64
#  13  SE_texture           198 non-null    float64
#  14  SE_perimeter         198 non-null    float64
# ...

# %%
#keys in dataset
df.keys()
# Out:
# Index(['status', 'time', 'mean_radius', 'mean_texture', 'mean_perimeter',
#        'mean_area', 'mean_smoothness', 'mean_compactness', 'mean_concavity',
#        'mean_concavepoints', 'mean_symmetry', 'mean_fractaldim', 'SE_radius',
#        'SE_texture', 'SE_perimeter', 'SE_area', 'SE_smoothness',
#        'SE_compactness', 'SE_concavity', 'SE_concavepoints', 'SE_symmetry',
#        'SE_fractaldim', 'worst_radius', 'worst_texture', 'worst_perimeter',
#        'worst_area', 'worst_smoothness', 'worst_compactness',
#        'worst_concavity', 'worst_concavepoints', 'worst_symmetry',
#        'worst_fractaldim', 'tsize', 'pnodes'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# featurs of each cells in numeric format
df['status']
# Out:
# 119513    N
# 8423      N
# 842517    N
# 843483    N
# 843584    R
#          ..
# 942640    N
# 943471    N
# 94547     N
# 947204    R
# 947489    N
# Name: status, Length: 198, dtype: object

# %%
df.status.unique()
# Out:
# array(['N', 'R'], dtype=object)

# %%
df['status'].value_counts()
# Out:
# N    151
# R     47
# Name: status, dtype: int64

# %%
sns.countplot(df['status'])
# Out:
# C:\Users\vijay\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
df['status'].replace(['N', 'R'],
                        [0, 1], inplace=True)

# %%
df
# Out:
#         status  time  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 119513       0    31        18.02         27.60          117.50     1013.0
# 8423         0    61        17.99         10.38          122.80     1001.0
# 842517       0   116        21.37         17.44          137.50     1373.0
# 843483       0   123        11.42         20.38           77.58      386.1
# 843584       1    27        20.29         14.34          135.10     1297.0
# ...        ...   ...          ...           ...             ...        ...
# 942640       0    10        22.52         21.92          146.90     1597.0
# 943471       0     8        15.44         31.18          101.00      740.4
# 94547        0    12        17.17         29.19          110.00      915.3
# 947204       1     3        21.42         22.84          145.00     1440.0
# 947489       0     6        16.70         28.13          110.30      885.4
#
# ...

# %%
sns.pairplot(df, hue = 'status')

# %%
sns.pairplot(df, hue = 'time', 
             vars = ['mean_radius', 'mean_texture', 'mean_perimeter', 'mean_area', 'mean_smoothness'] )

# %%
# counter plot of feature mean radius
plt.figure(figsize = (20,8))
sns.countplot(df['mean_radius'])

# %%
# Heatmap of Correlation matrix of breast cancer DataFrame
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot = True, cmap ='coolwarm', linewidths=2)

# %%
 X=df.drop(['status'], 1)
 Y= df['status']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors=3)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

cm = confusion_matrix(y_test, y_pred)
print(cm)
print('Accuracy' , accuracy_score(y_test, y_pred))

# %%
# K – Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 7, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
accuracy_score(y_test, y_pred)

# %%
error_rates = []

for a in range(1, 10):
    k = a
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    preds = knn.predict(X_test)
    error_rates.append(np.mean(y_test - preds))

plt.figure(figsize=(10, 7))
plt.plot(range(1,10),error_rates,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

# %%
import seaborn as sns
ax = sns.heatmap(cm, annot=True, cmap='summer',fmt='g')
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
##The visualization of the Confusion Matrix.
plt.show()

# %%
#Confusion matrix method using percentages 
ax = sns.heatmap(cm/np.sum(cm), annot=True, 
            fmt='.2%', cmap='Blues')
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13096\2375006770.py in <module>
#       1 #Confusion matrix method using percentages
# ----> 2 ax = sns.heatmap(cm/np.sum(cm), annot=True,
#       3             fmt='.2%', cmap='Blues')
#       4 ax.set_title('Seaborn Confusion Matrix with labels\n\n');
#       5 ax.set_xlabel('\nPredicted Values')
#
# NameError: name 'cm' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
